# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\fngur\\Desktop\\ml kodlar\\cimento.csv")

# %%
df
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 2      332.5  142.5     0.0  228.0               0.0            932.0
# 3      332.5  142.5     0.0  228.0               0.0            932.0
# 4      198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 0             676.0   28  79.99
# 1             676.0   28  61.89
# 2             594.0  270  40.27
# 3             594.0  365  41.05
# 4             825.5  360  44.30
# ...             ...  ...    ...
# 1025          768.3   28  44.28
# 1026          813.4   28  31.18
# 1027          780.0   28  23.70
# 1028          788.9   28  32.77
# 1029          761.5   28  32.40
#
# [1030 rows x 9 columns]

# %%
corr = df.corr()

# %%
corr
# Out:
#                     cement      slag    flyash     water  superplasticizer  \
# cement            1.000000 -0.275216 -0.397467 -0.081587          0.092386
# slag             -0.275216  1.000000 -0.323580  0.107252          0.043270
# flyash           -0.397467 -0.323580  1.000000 -0.256984          0.377503
# water            -0.081587  0.107252 -0.256984  1.000000         -0.657533
# superplasticizer  0.092386  0.043270  0.377503 -0.657533          1.000000
# coarseaggregate  -0.109349 -0.283999 -0.009961 -0.182294         -0.265999
# fineaggregate    -0.222718 -0.281603  0.079108 -0.450661          0.222691
# age               0.081946 -0.044246 -0.154371  0.277618         -0.192700
# csMPa             0.497832  0.134829 -0.105755 -0.289633          0.366079
#
#                   coarseaggregate  fineaggregate       age     csMPa
# cement                  -0.109349      -0.222718  0.081946  0.497832
# slag                    -0.283999      -0.281603 -0.044246  0.134829
# flyash                  -0.009961       0.079108 -0.154371 -0.105755
# water                   -0.182294      -0.450661  0.277618 -0.289633
# superplasticizer        -0.265999       0.222691 -0.192700  0.366079
# coarseaggregate          1.000000      -0.178481 -0.003016 -0.164935
# fineaggregate           -0.178481       1.000000 -0.156095 -0.167241
# age                     -0.003016      -0.156095  1.000000  0.328873
# csMPa                   -0.164935      -0.167241  0.328873  1.000000

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df.columns)
ax.set_yticklabels(df.columns)
plt.show()

# %%
corr
# Out:
#                     cement      slag    flyash     water  superplasticizer  \
# cement            1.000000 -0.275216 -0.397467 -0.081587          0.092386
# slag             -0.275216  1.000000 -0.323580  0.107252          0.043270
# flyash           -0.397467 -0.323580  1.000000 -0.256984          0.377503
# water            -0.081587  0.107252 -0.256984  1.000000         -0.657533
# superplasticizer  0.092386  0.043270  0.377503 -0.657533          1.000000
# coarseaggregate  -0.109349 -0.283999 -0.009961 -0.182294         -0.265999
# fineaggregate    -0.222718 -0.281603  0.079108 -0.450661          0.222691
# age               0.081946 -0.044246 -0.154371  0.277618         -0.192700
# csMPa             0.497832  0.134829 -0.105755 -0.289633          0.366079
#
#                   coarseaggregate  fineaggregate       age     csMPa
# cement                  -0.109349      -0.222718  0.081946  0.497832
# slag                    -0.283999      -0.281603 -0.044246  0.134829
# flyash                  -0.009961       0.079108 -0.154371 -0.105755
# water                   -0.182294      -0.450661  0.277618 -0.289633
# superplasticizer        -0.265999       0.222691 -0.192700  0.366079
# coarseaggregate          1.000000      -0.178481 -0.003016 -0.164935
# fineaggregate           -0.178481       1.000000 -0.156095 -0.167241
# age                     -0.003016      -0.156095  1.000000  0.328873
# csMPa                   -0.164935      -0.167241  0.328873  1.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# 1            954.75    103.0       1173.75     92.0       1558.75
# 2            939.25    131.0       1140.00    114.0       1554.50
# 3            948.25    172.0       1092.00    122.0       1583.75
# 4            835.50    131.0       1205.00    116.0       1490.00
# ...             ...      ...           ...      ...           ...
# 9352        1101.25    471.7        538.50    189.8       1374.25
# 9353        1027.00    353.3        603.75    179.2       1263.50
# 9354        1062.50    293.0        603.25    174.7       1240.75
# 9355         960.50    234.5        701.50    155.7       1041.00
# 9356        1047.25    265.2        654.00    167.7       1128.50
#
#       PT08.S5(O3)       T         RH        AH
# 0         1267.50  13.600  48.875001  0.757754
# 1          972.25  13.300  47.700000  0.725487
# 2         1074.00  11.900  53.975000  0.750239
# 3         1203.25  11.000  60.000000  0.786713
# 4         1110.00  11.150  59.575001  0.788794
# ...           ...     ...        ...       ...
# 9352      1728.50  21.850  29.250000  0.756824
# 9353      1269.00  24.325  23.725000  0.711864
# 9354      1092.00  26.900  18.350000  0.640649
# 9355       769.75  28.325  13.550000  0.513866
# 9356       816.00  28.500  13.125000  0.502804
#
# [9357 rows x 15 columns]>

# %%
y= df.iloc[:,:1]

# %%
y
# Out:
#       cement
# 0      540.0
# 1      540.0
# 2      332.5
# 3      332.5
# 4      198.6
# ...      ...
# 1025   276.4
# 1026   322.2
# 1027   148.5
# 1028   159.1
# 1029   260.9
#
# [1030 rows x 1 columns]

# %%
x=df.iloc[:,1:]

# %%
x
# Out:
#        slag  flyash  water  superplasticizer  coarseaggregate  fineaggregate  \
# 0       0.0     0.0  162.0               2.5           1040.0          676.0
# 1       0.0     0.0  162.0               2.5           1055.0          676.0
# 2     142.5     0.0  228.0               0.0            932.0          594.0
# 3     142.5     0.0  228.0               0.0            932.0          594.0
# 4     132.4     0.0  192.0               0.0            978.4          825.5
# ...     ...     ...    ...               ...              ...            ...
# 1025  116.0    90.3  179.6               8.9            870.1          768.3
# 1026    0.0   115.6  196.0              10.4            817.9          813.4
# 1027  139.4   108.6  192.7               6.1            892.4          780.0
# 1028  186.7     0.0  175.6              11.3            989.6          788.9
# 1029  100.5    78.3  200.6               8.6            864.5          761.5
#
#       age  csMPa
# 0      28  79.99
# 1      28  61.89
# 2     270  40.27
# 3     365  41.05
# 4     360  44.30
# ...   ...    ...
# 1025   28  44.28
# 1026   28  31.18
# 1027   28  23.70
# 1028   28  32.77
# 1029   28  32.40
#
# [1030 rows x 8 columns]

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y, x).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 cement   R-squared (uncentered):                   0.962
# Model:                            OLS   Adj. R-squared (uncentered):              0.962
# Method:                 Least Squares   F-statistic:                              3223.
# Date:                Thu, 11 Aug 2022   Prob (F-statistic):                        0.00
# Time:                        16:15:05   Log-Likelihood:                         -5653.7
# No. Observations:                1030   AIC:                                  1.132e+04
# Df Residuals:                    1022   BIC:                                  1.136e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# slag                -0.7607      0.024    -31.325      0.000      -0.808      -0.713
# flyash              -0.9989      0.035    -28.822      0.000      -1.067      -0.931
# water                1.6596      0.081     20.438      0.000       1.500       1.819
# superplasticizer     6.3145      0.459     13.754      0.000       5.414       7.215
# coarseaggregate      0.0692      0.017      4.008      0.000       0.035       0.103
# fineaggregate       -0.1639      0.020     -8.391      0.000      -0.202      -0.126
# age                 -0.4437      0.034    -13.065      0.000      -0.510      -0.377
# csMPa                3.6238      0.136     26.692      0.000       3.357       3.890
# ==============================================================================
# Omnibus:                       66.374   Durbin-Watson:                   0.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.600
# Skew:                           0.630   Prob(JB):                     8.56e-18
# Kurtosis:                       3.495   Cond. No.                         321.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
